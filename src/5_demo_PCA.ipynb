# %%
import pandas as pd

# %%
df_data = pd.read_csv("../results/4_one_hot.csv")
df_data
# Out:
#           age  bp_systolic  bp_diastolic    bp_pam     bp_pp  weight kg  \
# 0    0.842697     0.532020      0.608696  0.609338  0.376238   0.583333
# 1    0.741573     0.600985      0.626087  0.653564  0.495050   0.433333
# 2    0.865169     0.615764      0.739130  0.724811  0.396040   0.675000
# 3    0.865169     0.620690      0.626087  0.663389  0.534653   0.708333
# 4    0.820225     0.640394      0.695652  0.712531  0.495050   0.575000
# ..        ...          ...           ...       ...       ...        ...
# 505  0.898876     0.748768      0.713043  0.776408  0.693069   0.674167
# 506  0.752809     0.660099      0.756522  0.756757  0.465347   0.567500
# 507  0.865169     0.694581      0.695652  0.739553  0.603960   0.559167
# 508  0.685393     0.522167      0.504348  0.545453  0.475248   0.486667
# 509  0.775281     0.546798      0.626087  0.626534  0.386139   0.671667
#
#      height cm     imc_2  is_isolated  is_lof  response  sex_F  sex_M
# ...

# %%
df_data_not_use = df_data[["is_isolated", "is_lof", "response"]]
df_data_values = df_data.drop(columns=["is_isolated", "is_lof", "response"])

# %%
from sklearn.decomposition import PCA, SparsePCA, IncrementalPCA, FastICA

# %%
pca_instance = PCA()
pca_instance.fit(df_data_values.values)
pca_instance
# Out:
# PCA()

# %%
sparse_pca_instance = SparsePCA()
sparse_pca_instance.fit(df_data_values.values)
sparse_pca_instance
# Out:
# SparsePCA()

# %%
incremetal_PCA = IncrementalPCA()
incremetal_PCA.fit(df_data_values.values)
incremetal_PCA
# Out:
# IncrementalPCA()

# %%
pca_instance.explained_variance_
# Out:
# array([4.29033365e-01, 2.93471583e-02, 2.10766718e-02, 1.30778106e-02,
#        4.35739451e-03, 4.26698632e-03, 3.32465361e-05, 2.59677661e-12,
#        1.38005776e-17, 0.00000000e+00])

# %%
pca_instance.explained_variance_ratio_*100
# Out:
# array([8.56024883e+01, 5.85546481e+00, 4.20530359e+00, 2.60933815e+00,
#        8.69405139e-01, 8.51366528e-01, 6.63348460e-03, 5.18119469e-10,
#        2.75354758e-15, 0.00000000e+00])

# %%
data_transform = pca_instance.transform(df_data_values.values)
data_transform
# Out:
# array([[ 4.38391632e-01, -2.19749365e-01, -1.21712464e-02, ...,
#          2.04011694e-06, -3.85768084e-11, -1.08946685e-10],
#        [ 4.43508979e-01, -1.31755014e-01, -1.95833472e-01, ...,
#          2.06719863e-06, -3.91207067e-11, -1.10371719e-10],
#        [-9.80613986e-01, -7.63203925e-02,  3.42292344e-02, ...,
#         -2.28181554e-06,  4.31648051e-11,  1.21839511e-10],
#        ...,
#        [-9.73894417e-01,  7.85546174e-02, -1.22458435e-01, ...,
#         -2.08985079e-06,  3.95172783e-11,  1.11600625e-10],
#        [-9.70180584e-01, -2.51588603e-01, -1.81276899e-01, ...,
#          9.74388726e-08, -1.82842630e-12, -5.21494653e-12],
#        [-9.79489864e-01, -1.90379949e-01,  1.11850462e-02, ...,
#         -1.41940263e-07,  2.72482037e-12,  7.55313173e-12]])
