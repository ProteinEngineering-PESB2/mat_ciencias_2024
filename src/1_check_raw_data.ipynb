# %% [markdown]
# ## Revision y limpieza dataset
#
# - Leer el dataset
# - Analizar las features/descriptores
# - Limpieza de tipos de datos
# - Evaluar nulos
# - Evaluar outliers

# %%
import pandas as pd

# %%
df_data = pd.read_excel("../raw_data/Basal.xlsx")
df_data
# Out:
#      Unnamed: 0  Unnamed: 1  redcap_repeat_instrument  sex   age  \
# 0           NaN         NaN                       NaN  1.0  75.0
# 1           NaN         NaN                       NaN  1.0  66.0
# 2           NaN         NaN                       NaN  2.0  77.0
# 3           NaN         NaN                       NaN  1.0  77.0
# 4           NaN         NaN                       NaN  1.0  73.0
# ..          ...         ...                       ...  ...   ...
# 526         NaN         NaN                       NaN  2.0  67.0
# 527         NaN         NaN                       NaN  2.0  77.0
# 528         NaN         NaN                       NaN  2.0  61.0
# 529         NaN         NaN                       NaN  2.0  69.0
# 530         NaN         NaN                       NaN  NaN   NaN
#
#      t2m_pre_mean_rr t2m_pre_rmssd  t2m_pre_sd1  t2m_pre_pns  t2m_pre_mean_hr  \
# 0               74.8          21.7       274.00      -140.00               80
# 1               95.3          18.8       285.00       -54.00               63
# 2               87.7          11.7       303.00      -105.00               68
# 3               81.9          17.5       376.00      -106.00               73
# 4               84.6          13.6       295.00      -115.00               71
# ..               ...           ...          ...          ...              ...
# 526            790.0          16.9          NaN        -1.28               76
# 527            814.0          23.8          NaN        -0.98               74
# 528            912.0          16.6          NaN        -0.78               66
# 529           1016.0          16.9          NaN        -0.25               59
# 530             46.8           0.5         5.59      -307.00               46
#
#      ...  t2m_pre_lf  t2m_pre_vlf  bp_systolic  bp_diastolic      bp_pam  \
# 0    ...         713          172          108            70   82.666667
# 1    ...         226           29          122            72   88.666667
# 2    ...         137            9          125            85   98.333333
# 3    ...         130           14          126            72   90.000000
# 4    ...          66           18          130            80   96.666667
# ..   ...         ...          ...          ...           ...         ...
# 526  ...         196           88          134            87  102.666667
# 527  ...         261           39          141            80  100.333333
# 528  ...         301           27          106            58   74.000000
# 529  ...         189           16          111            72   85.000000
# 530  ...           2            1           80            52   66.000000
#
#      bp_pp  weight kg  height cm  height mt        imc
# 0       38       70.0        160       1.60  27.343750
# 1       50       52.0        149       1.49  23.422368
# 2       40       81.0        170       1.70  28.027682
# 3       54       85.0        160       1.60  33.203125
# 4       50       69.0        151       1.51  30.261831
# ..     ...        ...        ...        ...        ...
# 526     47       68.1        154       1.54  28.714792
# 527     61       67.1        152       1.52  29.042590
# 528     48       58.4        162       1.62  22.252705
# 529     39       80.6        180       1.80  24.876543
# 530     16       47.0        130       1.30        NaN
#
# [531 rows x 25 columns]
